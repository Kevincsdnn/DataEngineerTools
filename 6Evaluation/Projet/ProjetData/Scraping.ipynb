# %%
def fonction(string):
    string2 = ""
    for i in range(len(string)):
        if string[i:i+1] != "\t" and string[i:i+1] != "\n":
            string2+=string[i:i+1]
    return string2
fonction("EFBE\t\t\t\t\noz") #test de la fonction
# Out:
# 'EFBEoz'

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\anaconda\lib\site-packages (1.3.4)
# Requirement already satisfied: numpy>=1.17.3 in d:\anaconda\lib\site-packages (from pandas) (1.21.2)
# Requirement already satisfied: pytz>=2017.3 in d:\anaconda\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\anaconda\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
from bs4 import BeautifulSoup
import requests

def fonction1(link):
    response = requests.get(link)
    print(response)
    soup = BeautifulSoup(response.text, "html.parser")
    return soup

# %%
url2 = "https://fr.wikipedia.org/wiki/Liste_de_sondages_sur_l%27%C3%A9lection_pr%C3%A9sidentielle_fran%C3%A7aise_de_2022#Ann%C3%A9e_2022"

soup = fonction1(url2)
# Out:
# <Response [200]>

# %%
#for i in list[::2] :
sondage2022 = soup.find_all( class_='wikitable')
#for i in list(sondage2022)[1:] :
#    print(i)
    #print(BeautifulSoup(i))
sondage2021 = soup.find( class_='NavContent')
#sondage2021

# %%
X2022=[]
X2021=[]
bb= False

for j in sondage2022 :
    for i in j.find_all("td"):
        T= i.text
        if "28-31 décembre\n" in T :
            bb = True
            break
        if len (T)<20:
            X2022.append(T)
        
    if bb : 
        break
for i in sondage2021.find_all('td'):
    T= i.text
    if len (T)<20:
        X2021.append(T)
    

#print(X2022)

# %%
col = []

p = 1
for i in sondage2021.find_all('th'):
    if p < 38 :
        title = (fonction(i.text))
        col.append(title)
        while '' in col:
            col.remove('')
    p = p + 1
print(col)  

mois = ["janvier","février","mars","avril","mai","juin","juillet","aout","septembre","octobre","novembre","décembre"]
k= 1
for i in range (0,12) :
    mois[i] = k
    k = k+1
#print(mois)
# Out:
# ['Sondeur', 'Date', 'Échantillon', 'Arthaud(LO)', 'Poutou(NPA)', 'Roussel(PCF)', 'Mélenchon(LFI)', 'Montebourg(DVG)', 'Hidalgo(PS)', 'Taubira(Walwari)', 'Jadot(EÉLV)', 'Macron(LREM)', 'Pécresse(LR)', 'Dupont-Aignan(DLF)', 'Philippot(LP)', 'Le Pen(RN)', 'Zemmour(REC)', 'Lassalle(RES)', 'Asselineau(UPR)', 'Thouy(PA)']

# %%
import pandas as pd 
import numpy as np
from datetime import datetime


Y = []
        
for i in range (0,len(X2021)-1):
    if X2021[i] == 'OpinionWay\n':
        ligne= X2021[i:i+20]
        Y.append(ligne)
    if X2021[i] == 'Ifop\n' :
        ligne= X2021[i:i+20]
        Y.append(ligne)
    if X2021[i] == 'Harris Interactive\n' :
        ligne= X2021[i:i+20]
        Y.append(ligne)
    if X2021[i] == 'Harris-Interactive\n' :
        ligne= X2021[i:i+20]
        Y.append(ligne)
    if X2021[i] == 'Cluster17\n' :
        ligne= X2021[i:i+20]
        Y.append(ligne)
    if X2021[i] == 'BVA\n' :
        ligne= X2021[i:i+20]
        Y.append(ligne)
    if X2021[i] == 'Ipsos\n' :
        ligne= X2021[i:i+20]
        Y.append(ligne)
    if X2021[i] == 'Elabe\n' :
        ligne= X2021[i:i+20]
        Y.append(ligne)


    
data21 = pd.DataFrame(data = Y, columns = col)
data21[col] = data21[col].replace({'\n':''}, regex=True)
data21[col] = data21[col].replace({'\<':''}, regex=True)
data21[col] = data21[col].replace({'\,5':''}, regex=True)
#data21[col] = data21[col].replace({'\%':' '}, regex=True)
#data21.drop('Sondeur', inplace=True, axis=1)
data21.drop('Échantillon', inplace=True, axis=1)
data21['Date'] = data21['Date'].astype(str) + ' 2021'
data21['Date'] = data21['Date'].str.split('-').str.get(-1)
data21.drop(data21.tail(26).index,inplace=True)

data21.head()
# Out:
#               Sondeur              Date Arthaud(LO) Poutou(NPA) Roussel(PCF)  \
# 0  Harris-Interactive  31 décembre 2021         0 %         1 %          3 %
# 1           Cluster17  31 décembre 2021         0 %         1 %          1 %
# 2          OpinionWay  22 décembre 2021         1 %         1 %          2 %
# 3           Cluster17  22 décembre 2021         0 %         1 %          1 %
# 4               Elabe  20 décembre 2021         1 %         1 %          1 %
#
#   Mélenchon(LFI) Montebourg(DVG) Hidalgo(PS) Taubira(Walwari) Jadot(EÉLV)  \
# 0           10 %             1 %         4 %                —         7 %
# 1           13 %             1 %         2 %              4 %         4 %
# 2            8 %             1 %         4 %              3 %         6 %
# 3           12 %             1 %         2 %              7 %         5 %
# 4           11 %             2 %         3 %                —         5 %
#
#   Macron(LREM) Pécresse(LR) Dupont-Aignan(DLF) Philippot(LP) Le Pen(RN)  \
# 0         24 %         16 %                2 %           0 %       16 %
# 1         23 %         15 %                1 %           1 %       14 %
# 2         26 %         18 %                2 %             —       16 %
# 3         20 %         16 %                2 %           1 %       13 %
# 4         26 %         17 %                2 %           1 %       16 %
#
#   Zemmour(REC) Lassalle(RES) Asselineau(UPR) Thouy(PA)
# 0         16 %           0 %             0 %         —
# 1         15 %           1 %             1 %         —
# 2         12 %           1 %               —         —
# 3         14 %           1 %             1 %         —
# 4         13 %           1 %             1 %       1 %

# %%
W=[]
for i in range (0,len(X2022)):
    if X2022[i] == 'OpinionWay\n':
        ligne= X2022[i:i+20]
        W.append(ligne)
    if X2022[i] == 'Ifop\n' :
        ligne= X2022[i:i+20]
        W.append(ligne)
    if X2022[i] == 'Harris Interactive\n' :
        ligne= X2022[i:i+20]
        W.append(ligne)
    if X2022[i] == 'Harris-Interactive\n' :
        ligne= X2022[i:i+20]
        W.append(ligne)
    if X2022[i] == 'Cluster17\n' :
        ligne= X2022[i:i+20]
        W.append(ligne)
    if X2022[i] == 'BVA\n' :
        ligne= X2022[i:i+20]
        W.append(ligne)
    if X2022[i] == 'Ipsos\n' :
        ligne= X2022[i:i+20]
        W.append(ligne)
    if X2022[i] == 'Elabe\n' :
        ligne= X2022[i:i+20]
        W.append(ligne)


data22 =pd.DataFrame(data = W[:-1], columns = col)
data22[col] = data22[col].replace({'\n':''}, regex=True)
data22[col] = data22[col].replace({'\<':''}, regex=True)
data22[col] = data22[col].replace({'\,5':''}, regex=True)

#data22.drop('Sondeur', inplace=True, axis=1)
data22.drop('Échantillon', inplace=True, axis =1)
data22['Date'] = data22['Date'].astype(str) + ' 2022'
data22['Date'] = data22['Date'].str.split('-').str.get(-1)


data22.head()
# Out:
#       Sondeur             Date Arthaud(LO) Poutou(NPA) Roussel(PCF)  \
# 0  OpinionWay  31 janvier 2022         0 %         0 %          3 %
# 1        Ifop  31 janvier 2022         0 %         0 %          3 %
# 2  OpinionWay  27 janvier 2022         1 %         1 %          3 %
# 3        Ifop  27 janvier 2022         0 %         0 %          3 %
# 4  OpinionWay  27 janvier 2022         0 %         1 %          3 %
#
#   Mélenchon(LFI) Montebourg(DVG) Hidalgo(PS) Taubira(Walwari) Jadot(EÉLV)  \
# 0           10 %               —         3 %              5 %         5 %
# 1            9 %               —         3 %              4 %         5 %
# 2            9 %               —         2 %              5 %         6 %
# 3            9 %               —         3 %              3 %         5 %
# 4            9 %               —         3 %              5 %         5 %
#
#   Macron(LREM) Pécresse(LR) Dupont-Aignan(DLF) Philippot(LP) Le Pen(RN)  \
# 0         24 %         17 %                2 %             —       17 %
# 1         24 %         16 %                1 %             —       17 %
# 2         24 %         18 %                1 %             —       17 %
# 3         24 %         16 %                1 %             —       18 %
# 4         24 %         17 %                2 %             —       17 %
#
#   Zemmour(REC) Lassalle(RES) Asselineau(UPR) Thouy(PA)
# 0         13 %           1 %               —         —
# 1         13 %           1 %               —       0 %
# 2         13 %           1 %               —         —
# 3         13 %           1 %               —       0 %
# 4         13 %           1 %               —         —

# %%
lst1=[]
for j in range (2,19) :
    for i in data21[data21.columns[j]] :
        o1 = i.split('\xa0%')[0]
        if o1 == '<1':
            o1 = '1'
        if o1 == "—" :
            o1 = '0'
        if o1 == '<0,5':
            o1 = '0'
        if o1 == '0,5':
            o1 = '0'
        if o1 == '1%' :
            o1 = '1'
        o1 = int(o1)
        lst1+=[o1]
    nvSerie1 = pd.Series(lst1)
    data21[data21.columns[j]]=nvSerie1
    del lst1[:]



#data21

# %%
lst2=[]
import numpy as np
import re

#d2022 = data22['Date']
#data22.drop('Date', inplace=True, axis =1)

for j in range (2,19) :
    for i in data22[data22.columns[j]] :
        
        o2 = i.split('\xa0%')[0]
        
        
        if o2 == '<1':
            o2 = '1'
        if o2 == "—" :
            o2 = '0'
        if o2 == '<0,5':
            o2 = '0'
        if o2 == '0,5':
            o2 = '0'

        o2 = int(o2)
        lst2+=[o2]
    nvSerie2 = pd.Series(lst2)
    data22[data22.columns[j]]=nvSerie2
    del lst2[:]
    
    
#df.insert(2, "Date", d2022, True)
#data22

# %%
dataP = pd.concat([data22,data21],ignore_index=True)
#dataP
dataP['Date'] = dataP['Date'].replace("", " ")
dataP
# Out:
#                Sondeur               Date  Arthaud(LO)  Poutou(NPA)  \
# 0           OpinionWay    31 janvier 2022            0            0
# 1                 Ifop    31 janvier 2022            0            0
# 2           OpinionWay    27 janvier 2022            1            1
# 3                 Ifop    27 janvier 2022            0            0
# 4           OpinionWay    27 janvier 2022            0            1
# ..                 ...                ...          ...          ...
# 71          OpinionWay  23 septembre 2021            1            1
# 72  Harris-Interactive  20 septembre 2021            1            1
# 73                Ifop  15 septembre 2021            0            1
# 74  Harris-Interactive  13 septembre 2021            1            1
# 75               Elabe  13 septembre 2021            1            1
#
#     Roussel(PCF)  Mélenchon(LFI)  Montebourg(DVG)  Hidalgo(PS)  \
# 0              3              10                0            3
# 1              3               9                0            3
# 2              3               9                0            2
# 3              3               9                0            3
# 4              3               9                0            3
# ..           ...             ...              ...          ...
# 71             3               8                3            6
# 72             3              11                2            7
# 73             3               8                2            7
# 74             3              11                0            7
# 75             2               8                2            7
#
#     Taubira(Walwari)  Jadot(EÉLV)  Macron(LREM)  Pécresse(LR)  \
# 0                  5            5            24            17
# 1                  4            5            24            16
# 2                  5            6            24            18
# 3                  3            5            24            16
# 4                  5            5            24            17
# ..               ...          ...           ...           ...
# 71                 7           24             0            15
# 72                 6           23             0            14
# 73                 6           26             0            15
# 74                 7           24             1            15
# 75                 6           26             1            16
#
#     Dupont-Aignan(DLF)  Philippot(LP)  Le Pen(RN)  Zemmour(REC)  \
# 0                    2              0          17            13
# 1                    1              0          17            13
# 2                    1              0          17            13
# 3                    1              0          18            13
# 4                    2              0          17            13
# ..                 ...            ...         ...           ...
# 71                   0              2           0            20
# 72                   0              2           1            18
# 73                   0              3           0            20
# 74                   0              5           1            22
# 75                   1              5           1            23
#
#     Lassalle(RES)  Asselineau(UPR)  Thouy(PA)
# 0               1                0          0
# 1               1                0          0
# 2               1                0          0
# 3               1                0          0
# 4               1                0          0
# ..            ...              ...        ...
# 71             10                0          0
# 72             11                0          0
# 73              9                0          0
# 74              0                1          1
# 75              0                2          1
#
# [76 rows x 19 columns]

# %%
# for j in range (len(dataP['Date'])) :
#     for i in dataP['Date'] :
        
#         f = dataP['Date'].str.split(' ')[j][0]
#         t = dataP['Date'].str.split(' ')[j][1]
        
#         if t == 'janvier' :
#             t = '1'
#         if t == 'février' :
#             t = '2'
#         if t == 'mars' :
#             t = '3'
#         if t == 'avril' :
#             t = '4'
#         if t == 'mai' :
#             t = '5'
#         if t == 'juin' :
#             t = '6'
#         if t == 'juillet' :
#             t = '7'
#         if t == 'août' :
#             t = '8'
#         if t == 'septembre' :
#             t = '9'
#         if t == 'octobre' :
#             t = '10'
#         if t == 'novembre' :
#             t = '11'
#         if t == 'décembre' :
#             t = '12'
#         p = dataP['Date'].str.split(' ')[j][2]
#     m += [f +str(" ") + t +str(" ") + p]
#     nvSerie3 = pd.Series(m)
#     print(nvSerie3)
#     dataP['Date'] = nvSerie3
#     del m[:]
# dataP['Date'] = pd.to_datetime(dataP['Date'], format ='%d %m %Y')
# dataP.info()
# dataP

# %%
dataP.to_json('dataP.json', orient = 'split', compression = 'infer', index = 'true')
dataP = pd.read_json('dataP.json', orient ='split', compression = 'infer')
print(dataP)
# Out:
#                Sondeur               Date  Arthaud(LO)  Poutou(NPA)  \
# 0           OpinionWay    31 janvier 2022            0            0
# 1           OpinionWay    27 janvier 2022            1            1
# 2                 Ifop    27 janvier 2022            0            0
# 3           OpinionWay    27 janvier 2022            0            1
# 4                  BVA    26 janvier 2022            0            0
# ..                 ...                ...          ...          ...
# 70          OpinionWay  23 septembre 2021            1            1
# 71  Harris-Interactive  20 septembre 2021            1            1
# 72                Ifop  15 septembre 2021            0            1
# 73  Harris-Interactive  13 septembre 2021            1            1
# 74               Elabe  13 septembre 2021            1            1
#
#     Roussel(PCF)  Mélenchon(LFI)  Montebourg(DVG)  Hidalgo(PS)  \
# 0              3              10                0            3
# 1              3               9                0            2
# 2              3               9                0            3
# 3              3               9                0            3
# 4              3              10                0            3
# ..           ...             ...              ...          ...
# 70             3               8                3            6
# 71             3              11                2            7
# 72             3               8                2            7
# 73             3              11                0            7
# 74             2               8                2            7
#
#     Taubira(Walwari)  Jadot(EÉLV)  Macron(LREM)  Pécresse(LR)  \
# 0                  5            5            24            17
# 1                  5            6            24            18
# 2                  3            5            24            16
# 3                  5            5            24            17
# 4                  4            6            24            16
# ..               ...          ...           ...           ...
# 70                 7           24             0            15
# 71                 6           23             0            14
# 72                 6           26             0            15
# 73                 7           24             1            15
# 74                 6           26             1            16
#
#     Dupont-Aignan(DLF)  Philippot(LP)  Le Pen(RN)  Zemmour(REC)  \
# 0                    2              0          17            13
# 1                    1              0          17            13
# 2                    1              0          18            13
# 3                    2              0          17            13
# 4                    2              0          18            12
# ..                 ...            ...         ...           ...
# 70                   0              2           0            20
# 71                   0              2           1            18
# 72                   0              3           0            20
# 73                   0              5           1            22
# 74                   1              5           1            23
#
#     Lassalle(RES)  Asselineau(UPR)  Thouy(PA)
# 0               1                0          0
# 1               1                0          0
# 2               1                0          0
# 3               1                0          0
# 4               0                0          0
# ..            ...              ...        ...
# 70             10                0          0
# 71             11                0          0
# 72              9                0          0
# 73              0                1          1
# 74              0                2          1
#
# [75 rows x 19 columns]

# %%
def fonction(string):
    string2 = ""
    for i in range(len(string)):
        if string[i:i+1] != "\t" and string[i:i+1] != "\n":
            string2+=string[i:i+1]
    return string2
fonction("EFBE\t\t\t\t\noz") #test de la fonction
# Out:
# 'EFBEoz'
